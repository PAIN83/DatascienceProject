# %%
pip install numpy librosa scikit-learn matplotlib seaborn soundfile
# Out:
# Requirement already satisfied: numpy in c:\users\cicms\anaconda3\lib\site-packages (1.24.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: librosa in c:\users\cicms\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: scikit-learn in c:\users\cicms\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: matplotlib in c:\users\cicms\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: seaborn in c:\users\cicms\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: soundfile in c:\users\cicms\anaconda3\lib\site-packages (0.13.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (0.57.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (1.11.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in c:\users\cicms\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cicms\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cicms\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\cicms\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cicms\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cicms\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\cicms\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cicms\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\cicms\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cicms\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\cicms\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\cicms\anaconda3\lib\site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\cicms\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\cicms\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cicms\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\cicms\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\cicms\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\cicms\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\cicms\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cicms\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cicms\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cicms\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cicms\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2023.7.22)

# %% [markdown]
# ## Goal of the Project
#
# ### To build a simple Speech Emotion Detection system that:
#
# ### Extracts audio features (MFCC) from .wav files
#
# ### Trains a Machine Learning model (Logistic Regression)
#
# ### Predicts emotion from new audio
#
# ### Visualizes waveform, MFCC, confusion matrix, and class distribution
#
#
# ## Step 1: Import Required Libraries

# %%
import os
import glob
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %% [markdown]
# ## Step 2: Define Emotion Map

# %%
emotion_map={
    "01":"neutral",
    "02":"calm",
    "03":"happy",
    "04":"sad",
    "05":"angry"
}

# %% [markdown]
# ## Step 3: Visualize Audio (Waveform + MFCC)

# %%
def visualize_audio(file_path):
    y,sr=librosa.load(file_path)
    plt.figure(figsize=(14,6))
    
    plt.subplot(1,2,1)
    librosa.display.waveshow(y,sr=sr)
    plt.title("Waveform")
    
    plt.subplot(1,2,2)
    mfccs=librosa.feature.mfcc(y=y,sr=sr,n_mfcc=13)
    librosa.display.specshow(mfccs,x_axis='time')
    plt.colorbar()
    plt.title("MFCC")
    
    plt.suptitle(f"Visualization of {os.path.basename(file_path)}",fontsize=14)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Step 4: Extract Features from Audio

# %%
def extract_features(file_path):
    y,sr=librosa.load(file_path,duration=3,offset=0.5)
    mfccs=librosa.feature.mfcc(y=y,sr=sr,n_mfcc=40)
    return np.mean(mfccs.T,axis=0)

# %% [markdown]
# ## Step 5: Load Dataset

# %%
def load_data(data_path):
    X,y=[],[]
    for file in os.listdir(data_path):
        if file.endswith(".wav"):
            emotion_code=file.split("-")[2]
            emotion=emotion_map.get(emotion_code)
            if emotion:
                features=extract_features(os.path.join(data_path,file))
                X.append(features)
                y.append(emotion)
    return np.array(X),np.array(y)

# %% [markdown]
# ## Step 6: Set Data Path and Load Data

# %%
data_path=r"C:\Users\CICMS\Desktop\ML\Speech Emotion\Actor_02"
X,y=load_data(data_path)
# Out:
# C:\Users\CICMS\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ## Step 7: Split Dataset for Training

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# ## Step 8: Train the Model

# %%
model=LogisticRegression(max_iter=1000)
model.fit(X_train,y_train)
# Out:
# C:\Users\CICMS\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## Step 9: Evaluate Model Performance

# %%
y_pred=model.predict(X_test)
print("\n Classification Report:\n")
print(classification_report(y_test,y_pred))
print(f"Accuracy:{accuracy_score(y_test,y_pred):.2f}")
# Out:
#  Classification Report:
#
#               precision    recall  f1-score   support
#
#        angry       1.00      1.00      1.00         3
#         calm       1.00      1.00      1.00         1
#        happy       1.00      1.00      1.00         3
#          sad       1.00      1.00      1.00         2
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
# Accuracy:1.00

# %% [markdown]
# ## Step 10: Plot Confusion Matrix

# %%
plt.figure(figsize=(8,6))
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,fmt="d",cmap="YlGnBu",
           xticklabels=model.classes_,yticklabels=model.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## Step 11: Show Class Distribution

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=y)
plt.title("Class Distribution in Dataset")
plt.xlabel("Emotion")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## step 12: Automatically Select a File and Predict

# %%
def predict_emotion(audio_path, model):
    features = extract_features(audio_path).reshape(1, -1)
    prediction = model.predict(features)[0]
    print(f"Predicted Emotion: {predict_emotion}")
    visualize_audio(audio_path)
    
wav_files=glob.glob(data_path+r"\*.wav")

if not wav_files:
    print("No.wav files found.")
else:
    test_audio_path=wav_files[0]
    print(f"Testing on file:{test_audio_path}")
    predict_emotion(test_audio_path,model)
# Out:
# Testing on file:C:\Users\CICMS\Desktop\ML\Speech Emotion\Actor_02\03-01-01-01-01-01-02.wav
# Predicted Emotion: <function predict_emotion at 0x000001BD39398F40>
